# %%
# filename = "3000728773-Schedule C - Pricing Attachment I.xls"   --- more than 15line of LONG des
# filename = "3000743525-Schedule C - Pricing Attachment I.xls"   ---- roman numbers4

# %%
# # filename = "3000754591-Schedule C - Pricing Attachment I.xls"  ---- FOLDER AND SUB FOLDER SEQ ERROR

# 02.00 Surface Preparation',
# 04.00 Tank Painting Work',
# 05.00 Material Handling',
# 06.00 Welding and Miscellanneous Tank Repairs',
# 08.00 Sand / Cement',
# 09.00 Civil Works',
# 10.00 Pressure Grouting of Tank Bottoms',
# 11.00 Electrical Repair /Installation WORK',
# 12.00 Tank Testing and Inspection',
# 13.00 Remove Washwater, Sludges, Products or',
# ============================================
# 01.01 Blind & Spectacle
# 01.02 Cover & Manway
# 01.03 Manway Gasket
# 03.01 Solvent Cleanin

# 06.10 Seal Fabric and Rubber Seal Repairs',
# 06.11 Jack Knife & Drain',
# 06.12 Rolling Ladders',
# 06.13 Miscellaneous Works',
# 06.14 Install Air Foam System',
# 06.15 Raising and Lowering of Roof Support',
# 06.16 Grind/Remove Weld Cracks',
# 06.17 Perform Thermit Welding (Cadweld)',
# 06.18 Installation of Drip Plate',
# 06.19 Rim Vents',
# 06.20 Remove or Reinstall Main Inlet',
# 06.21 Hydrotest Valves, 150 lb.or more',
# 06.22 Cleaning Bolts and Others'}

# (^[0-9]{1,2}[.][1-9]{1,2})(\s|\S|)[a-zA-Z].+

# %%
# filename = "3000764586-Schedule C - Pricing Attachment I.xls"


# 0: '00001 PAINTING AND COATING SERVICES',
# 01.00 Internal Surface Repair',
# 1.01 Saudi Aramco Supplied Materials',
# 1.02 Contractor supplied materials',
# 02.00 External Surface Prepration',
# 2.01 Saudi Aramco Supplied Materials',
# 2.02 Contractor supplied materials',
# 03.00 Internal Coating',
# 3.01 Saudi Aramco Supplied Materials',
# 3.02 Contractor supplied materials',
# 04.00 External Coating',
# 4.01 Saudi Aramco Supplied Materials',
# 4.02 Contractor supplied materials',
# 05.00 Non-APCS',
# 5.01 Primer Saudi Aramco Supplied Materials',
# 5.02 Top Coat Saudi Aramco Supplied aterials',
# 5.03 Payment by Contractor Supplly Parts Form',
# 06.00 Labor Rates',
# 07.00 Equipment Rate',
# 08.00 Surface Protection',
#  720: '09.00 Distance Premium',
#  726: '10.00 Others',
#  760: '11.00 Pipe Internal Blasting and Coating',
#  856: '12.00 Fiscal Measure'}

# %%
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
filename = "3000599798-Schedule C - Pricing Attachment I.xls"

# %%
# start = datetime.now()
df = pd.read_excel(filename)
df
# Out:
#     Unnamed: 0       Unnamed: 1                             Unnamed: 2  \
# 0          NaN     Vendor Name:                    HCL ARABIA CO. LTD.
# 1          NaN       Vendor No:                               10053811
# 2          NaN       RFQ Title:  IT Application Development & Implmnt.
# 3          NaN          RFQ No:                             6000106938
# 4          NaN  Requisition No:                             3000599798
# ..         ...              ...                                    ...
# 314        NaN              NaN                                    NaN
# 315        NaN              NaN                                    NaN
# 316        NaN              NaN                                    NaN
# 317        NaN              NaN                                    NaN
# 318        NaN              NaN                                    NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# ...

# %%
df.dropna(how = 'all', axis = 0, inplace = True)
df.dropna(how = 'all', axis = 1, inplace = True)
df
# Out:
#     Unnamed: 0       Unnamed: 1  \
# 0          NaN     Vendor Name:
# 1          NaN       Vendor No:
# 2          NaN       RFQ Title:
# 3          NaN          RFQ No:
# 4          NaN  Requisition No:
# ..         ...              ...
# 214        NaN              NaN
# 215        NaN              NaN
# 216        NaN              NaN
# 217         10              NaN
# 318        NaN              NaN
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                  HCL ARABIA CO. LTD.        NaN        NaN
# 1                                             10053811        NaN        NaN
# 2                IT Application Development & Implmnt.        NaN        NaN
# 3                                           6000106938   Version:          0
# 4                                           3000599798        NaN        NaN
# ..                                                 ...        ...        ...
# ...

# %%
# df.fillna('',inplace = True, axis = 0)
df.reset_index(drop = True, inplace = True)
df
# Out:
#     Unnamed: 0       Unnamed: 1  \
# 0          NaN     Vendor Name:
# 1          NaN       Vendor No:
# 2          NaN       RFQ Title:
# 3          NaN          RFQ No:
# 4          NaN  Requisition No:
# ..         ...              ...
# 213        NaN              NaN
# 214        NaN              NaN
# 215        NaN              NaN
# 216         10              NaN
# 217        NaN              NaN
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                  HCL ARABIA CO. LTD.        NaN        NaN
# 1                                             10053811        NaN        NaN
# 2                IT Application Development & Implmnt.        NaN        NaN
# 3                                           6000106938   Version:          0
# 4                                           3000599798        NaN        NaN
# ..                                                 ...        ...        ...
# ...

# %%
df4 = df.iloc[3:5,1:3]
df4
# Out:
#         Unnamed: 1  Unnamed: 2
# 3          RFQ No:  6000106938
# 4  Requisition No:  3000599798

# %%
df[7:10]
# Out:
#    Unnamed: 0       Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 7         NaN           Title:          NaN        NaN        NaN        NaN
# 8         NaN            Date:          NaN        NaN        NaN        NaN
# 9  Line\nItem  Service\nNumber  Description   Quantity       Unit        CUR
#
#    Unnamed: 6 Unnamed: 8 Unnamed: 10  Unnamed: 11
# 7         NaN        NaN         NaN          NaN
# 8         NaN        NaN         NaN          NaN
# 9  Unit Price    Per UOM         NaN          NaN

# %%
col = list(df.values[9][:7])
col
# Out:
# ['Line\nItem',
#  'Service\nNumber',
#  'Description',
#  'Quantity',
#  'Unit',
#  'CUR',
#  'Unit Price']

# %%
# df.iloc[9:, :8]

# %%
col1 = []
for i in col:
    col1.append(re.sub(r'[\n\s]', '_', i))
col1
# Out:
# ['Line_Item',
#  'Service_Number',
#  'Description',
#  'Quantity',
#  'Unit',
#  'CUR',
#  'Unit_Price']

# %%
df.iloc[9:10]
# Out:
#    Unnamed: 0       Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 9  Line\nItem  Service\nNumber  Description   Quantity       Unit        CUR
#
#    Unnamed: 6 Unnamed: 8 Unnamed: 10  Unnamed: 11
# 9  Unit Price    Per UOM         NaN          NaN

# %%
df1 = df.iloc[11:, :7]
df1.columns = col1
df1.reset_index(drop = True,inplace = True)
df1
# Out:
#     Line_Item Service_Number  \
# 0         NaN            NaN
# 1          10            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
# ..        ...            ...
# 202       NaN            NaN
# 203       NaN            NaN
# 204       NaN            NaN
# 205        10            NaN
# 206       NaN            NaN
#
#                                            Description Quantity Unit  CUR  \
# 0          00001 IT Application Development & Implmnt.      NaN  NaN  NaN
# 1                           IT Application Development      NaN   PU  SAR
# 2                                                  NaN      NaN  NaN  NaN
# 3                       1.0 Time Unit Rates Release PO      NaN  NaN  NaN
# 4                                   1.1 Man-Hour Rates      NaN  NaN  NaN
# ..                                                 ...      ...  ...  ...
# 202  required Saudization level as per Attachment I...      NaN  NaN  NaN
# ...

# %%
df1.dropna(how = 'all', axis = 0, inplace = True)
# df1.dropna(how = 'all', axis = 1, inplace = True)
df1.reset_index(drop = True,inplace = True)
df1
# Out:
#     Line_Item Service_Number  \
# 0         NaN            NaN
# 1          10            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
# ..        ...            ...
# 186        20            NaN
# 187       NaN            NaN
# 188       NaN            NaN
# 189       NaN            NaN
# 190        10            NaN
#
#                                            Description Quantity Unit  CUR  \
# 0          00001 IT Application Development & Implmnt.      NaN  NaN  NaN
# 1                           IT Application Development      NaN   PU  SAR
# 2                       1.0 Time Unit Rates Release PO      NaN  NaN  NaN
# 3                                   1.1 Man-Hour Rates      NaN  NaN  NaN
# 4                                1.1.1 National Market      NaN  NaN  NaN
# ..                                                 ...      ...  ...  ...
# 186                              Deduction Per manhour      NaN  VAL  SAR
# ...

# %%
pd.set_option('display.max_rows', None)
df1
# Out:
#     Line_Item Service_Number  \
# 0         NaN            NaN
# 1          10            NaN
# 2         NaN            NaN
# 3         NaN            NaN
# 4         NaN            NaN
# 5          10            NaN
# 6          20            NaN
# 7          30            NaN
# 8          40            NaN
# 9          50            NaN
# 10         60            NaN
# 11         70            NaN
# 12         80            NaN
# 13         90            NaN
# 14        100            NaN
# 15        NaN            NaN
# 16        110            NaN
# 17        120            NaN
# 18        130            NaN
# 19        140            NaN
# 20        150            NaN
# 21        160            NaN
# 22        170            NaN
# 23        180            NaN
# 24        NaN            NaN
# 25         10            NaN
# 26         20            NaN
# 27         30            NaN
# 28         40            NaN
# 29         50            NaN
# 30         60            NaN
# ...

# %%
# import re

# regex_pattern = r"^(?=[MDCLXVI])M*(C[MD]|D?C{0,3})(X[CL]|L?X{0,3})(I[XV]|V?I{0,3})$"
# your_input = input('Please enter a roman numeral:')
# if re.match(regex_pattern, your_input, re.IGNORECASE):
#     print('YOur roman numeral was valid. Welcome.')
# else:
#     print('Invalid Roman Numeral')

# %%
# folder1 = {}

# for idx,i in enumerate(df1['Description']):
#     val = re.search(r'\b^((?=[MDCLXVI])M*(C[MD]|D?C{0,3})(X[CL]|L?X{0,3})(I[XV]|V?I{0,3}))(\s|\S|)[a-zA-Z].+\b', i)

#     if val != None:
# #         print(val.group().strip())
        
# #         df2['ref_data'] = 
#         folder1[idx] = val.group().strip()
# #         print(idx, val.group())
        
# folder1

# %%
df1.fillna('',inplace = True, axis = 0)

# %%
df1
# Out:
#     Line_Item Service_Number  \
# 0
# 1          10
# 2
# 3
# 4
# 5          10
# 6          20
# 7          30
# 8          40
# 9          50
# 10         60
# 11         70
# 12         80
# 13         90
# 14        100
# 15
# 16        110
# 17        120
# 18        130
# 19        140
# 20        150
# 21        160
# 22        170
# 23        180
# 24
# 25         10
# 26         20
# 27         30
# 28         40
# 29         50
# 30         60
# 31         70
# 32         80
# 33         90
# 34        100
# 35
# 36        110
# 37        120
# 38        130
# 39        140
# 40        150
# 41        160
# 42
# 43         10
# 44         20
# 45         30
# 46         40
# 47         50
# 48         60
# 49         70
# 50         80
# 51         90
# 52        100
# 53
# 54        110
# 55        120
# 56        130
# 57        140
# 58        150
# 59        160
# 60
# 61
# 62         10
# 63         20
# 64         30
# 65         40
# 66         50
# 67         60
# ...

# %%
df1.columns
# Out:
# Index(['Line_Item', 'Service_Number', 'Description', 'Quantity', 'Unit', 'CUR',
#        'Unit_Price'],
#       dtype='object')

# %%
# rr = pd.read_excel('alok_sample_09_09_22.xlsx', 'Reference')
# rr.columns

# %%
df1[:1]
# Out:
#   Line_Item Service_Number                                  Description  \
# 0                           00001 IT Application Development & Implmnt.
#
#   Quantity Unit CUR Unit_Price
# 0

# %%
# rr[:1]

# %%
# df1.rename(columns = {'Line0AItem':'Contract Line Item'})

# %%
# df1.insert(0, 'SMR No', '')
# df1.insert(3, 'ERP No', '')
# df1.insert(5, 'File Name', '')
# df1.insert(2, 'RFQ_NO', df4['Unnamed: 2'][3])
# df1.insert(1, 'Requisition_No', df4['Unnamed: 2'][4])
# df1.insert(6, 'Folder_1', '')
# df1.insert(7, 'Folder_2', '')
# df1.insert(8, 'Folder_3', '')
# df1.insert(9, 'Folder De', '')

# %%
df1['Description'] = df1['Description'].apply(lambda x : x.strip())

# %%
df4
# Out:
#         Unnamed: 1  Unnamed: 2
# 3          RFQ No:  6000106938
# 4  Requisition No:  3000599798

# %%
df4['Unnamed: 2'][3]
# Out:
# 6000106938

# %%
df1.insert(2, 'RFQ_NO', df4['Unnamed: 2'][3])
df1.insert(3, 'Requisition_No', df4['Unnamed: 2'][4])
df1.insert(4, 'Folder_1', '')
df1.insert(5, 'Folder_2', '')
df1.insert(6, 'Folder_3', '')

# %%
# df1[]

# %%
df1
# Out:
#     Line_Item Service_Number      RFQ_NO  Requisition_No Folder_1 Folder_2  \
# 0                             6000106938      3000599798
# 1          10                 6000106938      3000599798
# 2                             6000106938      3000599798
# 3                             6000106938      3000599798
# 4                             6000106938      3000599798
# 5          10                 6000106938      3000599798
# 6          20                 6000106938      3000599798
# 7          30                 6000106938      3000599798
# 8          40                 6000106938      3000599798
# 9          50                 6000106938      3000599798
# 10         60                 6000106938      3000599798
# 11         70                 6000106938      3000599798
# 12         80                 6000106938      3000599798
# 13         90                 6000106938      3000599798
# 14        100                 6000106938      3000599798
# ...

# %%
dic = {}

for idx,i in enumerate(df1['Description']):
    val = re.search(r'(^([0-9]{4,8}|[0-9]{1,2}[.][0-9]{1,2}|[0-9]{1}[.][0-9]{1}[.][0-9]{1}))(\s|\S|)[a-zA-Z].+', i)

    if val != None:
#         print(val.group().strip())
        
#         df2['ref_data'] = 
        dic[idx] = val.group().strip()
#         print(idx, val.group())
        
dic
# Out:
# {0: '00001 IT Application Development & Implmnt.',
#  2: '1.0 Time Unit Rates Release PO',
#  3: '1.1 Man-Hour Rates',
#  4: '1.1.1 National Market',
#  24: '1.1.2 Western Market',
#  42: '1.1.3 Eastern Market',
#  60: '1.2 Man-Day Rates',
#  61: '1.2.1 National Market',
#  81: '1.2.2 Western Market',
#  99: '1.2.3 Eastern Market',
#  117: '1.3 Man-Month Rates',
#  118: '1.3.1 National Market',
#  138: '1.3.2 Western Market',
#  156: '1.3.3 Eastern Market',
#  174: '2.0 SAUDI ARAMCO Project Team (PT) Office',
#  176: '3.0 Sponsorship Of Training & Certification',
#  179: '4.0 Agreed Liquidated Damages',
#  182: '5.0 Saudization Penalty',
#  189: '6.0 Lump Sum Release PO'}

# %%
data = pd.DataFrame(columns = ['key', 'value'])
data['key'] = dic.keys()
data['value'] = dic.values()
# data.to_excel('data.xlsx', index = False)
data
# Out:
#     key                                        value
# 0     0  00001 IT Application Development & Implmnt.
# 1     2               1.0 Time Unit Rates Release PO
# 2     3                           1.1 Man-Hour Rates
# 3     4                        1.1.1 National Market
# 4    24                         1.1.2 Western Market
# 5    42                         1.1.3 Eastern Market
# 6    60                            1.2 Man-Day Rates
# 7    61                        1.2.1 National Market
# 8    81                         1.2.2 Western Market
# 9    99                         1.2.3 Eastern Market
# 10  117                          1.3 Man-Month Rates
# 11  118                        1.3.1 National Market
# 12  138                         1.3.2 Western Market
# 13  156                         1.3.3 Eastern Market
# 14  174    2.0 SAUDI ARAMCO Project Team (PT) Office
# 15  176  3.0 Sponsorship Of Training & Certification
# 16  179                4.0 Agreed Liquidated Damages
# ...

# %%
folder1 = {}

for idx,i in enumerate(df1['Description']):
    val = re.search(r'(^([0-9]{4,8}|[0-9]{1,2}[.][0]{1,2}|[0-9]{1}[.][0]{1}))(\s|\S|)[a-zA-Z].+', i)

    if val != None:
#         print(val.group().strip())
        
#         df2['ref_data'] = 
        folder1[idx] = val.group().strip()
#         print(idx, val.group())
        
folder1
# Out:
# {0: '00001 IT Application Development & Implmnt.',
#  2: '1.0 Time Unit Rates Release PO',
#  174: '2.0 SAUDI ARAMCO Project Team (PT) Office',
#  176: '3.0 Sponsorship Of Training & Certification',
#  179: '4.0 Agreed Liquidated Damages',
#  182: '5.0 Saudization Penalty',
#  189: '6.0 Lump Sum Release PO'}

# %%
#     val = re.search(r'([0-9]{1,5}|[0-9]{1,3}[.][0-9]{1,3})(\s|\S)[a-zA-Z]{8,100}.+', i)

folder2 = {}

for idx,i in enumerate(df1['Description']):
    val = re.search(r'(^[0-9]{1,2}[.]([1-9]{1}[0-9]{1}|[1-9]{1}))(\s|\S|)[a-zA-Z].+', i)

    if val != None:
#         print(val.group().strip())
        
#         df2['ref_data'] = 
        folder2[idx] = val.group().strip()
#         print(idx, val.group())
        
folder2
# Out:
# {3: '1.1 Man-Hour Rates', 60: '1.2 Man-Day Rates', 117: '1.3 Man-Month Rates'}

# %%
#     val = re.search(r'([0-9]{1,5}|[0-9]{1,3}[.][0-9]{1,3})(\s|\S)[a-zA-Z]{8,100}.+', i)

folder3 = {}

for idx,i in enumerate(df1['Description']):
    val = re.search(r'(^[0-9]{1}[.][0-9]{1}[.][0-9]{1})(\s|\S|)[a-zA-Z].+', i)
#     print(i)
    if val != None:
#         print(val.group().strip())
        
#         df2['ref_data'] = 
        folder3[idx] = val.group().strip()
#         print(idx, val.group())
        
folder3
# Out:
# {4: '1.1.1 National Market',
#  24: '1.1.2 Western Market',
#  42: '1.1.3 Eastern Market',
#  61: '1.2.1 National Market',
#  81: '1.2.2 Western Market',
#  99: '1.2.3 Eastern Market',
#  118: '1.3.1 National Market',
#  138: '1.3.2 Western Market',
#  156: '1.3.3 Eastern Market'}

# %%
folder3
# Out:
# {4: '1.1.1 National Market',
#  24: '1.1.2 Western Market',
#  42: '1.1.3 Eastern Market',
#  61: '1.2.1 National Market',
#  81: '1.2.2 Western Market',
#  99: '1.2.3 Eastern Market',
#  118: '1.3.1 National Market',
#  138: '1.3.2 Western Market',
#  156: '1.3.3 Eastern Market'}

# %%
# lol = list(folder1.keys())
# lol1 = list(folder1.values())
# #         df1 = df1[lol[0]:lol[-1]+1]
# for i in range(len(lol)):
#     try:
#         df1['Folder_1'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
#     except IndexError:
#         df1['Folder_1'].iloc[range(lol[i] , len(df1))] = lol1[i]

# %%
# qq = list(folder1.keys())
# qq1 = (list(folder2.keys()))

# a = None

# for i in qq:
#     if i > qq1[-1]:
#         a = i
#         break

# lol = list(folder2.keys())
# lol1 = list(folder2.values())
# # df1 = df1[lol[0]:a]

# for i in range(len(lol)):
#     try:
#         df1['Folder_2'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
#     except IndexError:
#         df1['Folder_2'].iloc[range(lol[i] , a)] = lol1[i]

# %%
def value_insert(folder1, df1):

    if folder1:
        lol = list(folder1.keys())
        lol1 = list(folder1.values())
#         df1 = df1[lol[0]:lol[-1]+1]
        for i in range(len(lol)):
            try:
                df1['Folder_1'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
            except IndexError:
                df1['Folder_1'].iloc[range(lol[i] , len(df1))] = lol1[i]
    
#         elif folder3 == dic:
#             try:
#                 df1['Folder_3'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
#             except IndexError:
#                 df1['Folder_3'].iloc[range(lol[i] , len(df1))] = lol1[i]
            
    
    return df1

    #     print(lol[i] , lol[i+1])

# %%
if len(folder1) != 0:
    value_insert(folder1, df1)
else:
    print('Folder1 is Empty')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df1
# Out:
#     Line_Item Service_Number      RFQ_NO  Requisition_No  \
# 0                             6000106938      3000599798
# 1          10                 6000106938      3000599798
# 2                             6000106938      3000599798
# 3                             6000106938      3000599798
# 4                             6000106938      3000599798
# 5          10                 6000106938      3000599798
# 6          20                 6000106938      3000599798
# 7          30                 6000106938      3000599798
# 8          40                 6000106938      3000599798
# 9          50                 6000106938      3000599798
# 10         60                 6000106938      3000599798
# 11         70                 6000106938      3000599798
# 12         80                 6000106938      3000599798
# 13         90                 6000106938      3000599798
# 14        100                 6000106938      3000599798
# ...

# %%
def value_insert1(folder1, folder2, df1):

    qq = list(folder1.keys())
    qq1 = (list(folder2.keys()))

    a = None

    for i in qq:
        if i > qq1[-1]:
            a = i
            break

    lol = list(folder2.keys())
    lol1 = list(folder2.values())
#         df1 = df1[lol[0]:a]
    print(a)
    for i in range(len(lol)):
        try:
            df1['Folder_2'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
        except IndexError:
            df1['Folder_2'].iloc[range(lol[i] , a)] = lol1[i]
    
    return df1

# %%
if ((len(folder1) != 0) and (len(folder2) != 0)):
    value_insert1(folder1, folder2, df1)
else:
    print('Folder2 is Empty')
df1
# Out:
# 174
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#     Line_Item Service_Number      RFQ_NO  Requisition_No  \
# 0                             6000106938      3000599798
# 1          10                 6000106938      3000599798
# 2                             6000106938      3000599798
# 3                             6000106938      3000599798
# 4                             6000106938      3000599798
# 5          10                 6000106938      3000599798
# 6          20                 6000106938      3000599798
# 7          30                 6000106938      3000599798
# 8          40                 6000106938      3000599798
# ...

# %%
def value_insert2(folder1, folder3, df1):

    qq = list(folder1.keys())
    qq1 = (list(folder3.keys()))

    a = None

    for i in qq:
        if i > qq1[-1]:
            a = i
            break

    lol = list(folder3.keys())
    lol1 = list(folder3.values())
#         df1 = df1[lol[0]:a]

    for i in range(len(lol)):
        try:
            df1['Folder_3'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
        except IndexError:
            df1['Folder_3'].iloc[range(lol[i] , a)] = lol1[i]
    
    return df1

# %%
len(folder2) != 0
# Out:
# True

# %%
if ((len(folder1) != 0) and (len(folder3) != 0)):
    value_insert2(folder1, folder3, df1)
else:
    print('Folder3 is Empty')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df1
# Out:
#     Line_Item Service_Number      RFQ_NO  Requisition_No  \
# 0                             6000106938      3000599798
# 1          10                 6000106938      3000599798
# 2                             6000106938      3000599798
# 3                             6000106938      3000599798
# 4                             6000106938      3000599798
# 5          10                 6000106938      3000599798
# 6          20                 6000106938      3000599798
# 7          30                 6000106938      3000599798
# 8          40                 6000106938      3000599798
# 9          50                 6000106938      3000599798
# 10         60                 6000106938      3000599798
# 11         70                 6000106938      3000599798
# 12         80                 6000106938      3000599798
# 13         90                 6000106938      3000599798
# 14        100                 6000106938      3000599798
# ...

# %%
# df1.drop(list(data.key.values))

# %%
data
# Out:
#     key                                        value
# 0     0  00001 IT Application Development & Implmnt.
# 1     2               1.0 Time Unit Rates Release PO
# 2     3                           1.1 Man-Hour Rates
# 3     4                        1.1.1 National Market
# 4    24                         1.1.2 Western Market
# 5    42                         1.1.3 Eastern Market
# 6    60                            1.2 Man-Day Rates
# 7    61                        1.2.1 National Market
# 8    81                         1.2.2 Western Market
# 9    99                         1.2.3 Eastern Market
# 10  117                          1.3 Man-Month Rates
# 11  118                        1.3.1 National Market
# 12  138                         1.3.2 Western Market
# 13  156                         1.3.3 Eastern Market
# 14  174    2.0 SAUDI ARAMCO Project Team (PT) Office
# 15  176  3.0 Sponsorship Of Training & Certification
# 16  179                4.0 Agreed Liquidated Damages
# ...

# %%
df1.columns
# Out:
# Index(['Line_Item', 'Service_Number', 'RFQ_NO', 'Requisition_No', 'Folder_1',
#        'Folder_2', 'Folder_3', 'Description', 'Quantity', 'Unit', 'CUR',
#        'Unit_Price'],
#       dtype='object')

# %%
k = data.key.to_list()
for i in range(len(k[:1])):
    try:
#         print('try')
        df2 = (df1.iloc[range(k[i], k[i+1])])
    except:
#         print('exception index error')
        df2 = (df1.iloc[range(k[i], len(df1))])
#     print(df2)
#     print(len(df2))
    folder_des = ''
    short_des = ''
    long_des = ''
    for i in range(len(df2)):
        while df2['Line_Item'][i] == '':
            folder_des = ' '.join(df2['Description'][i])
            continue
        if df2['Line_Item'][i] != '':
            short_des = df2['Description'][i]
# Out:
# 2

# %%
df1
# Out:
#     Line_Item Service_Number      RFQ_NO  Requisition_No  \
# 0                             6000106938      3000599798
# 1          10                 6000106938      3000599798
# 2                             6000106938      3000599798
# 3                             6000106938      3000599798
# 4                             6000106938      3000599798
# 5          10                 6000106938      3000599798
# 6          20                 6000106938      3000599798
# 7          30                 6000106938      3000599798
# 8          40                 6000106938      3000599798
# 9          50                 6000106938      3000599798
# 10         60                 6000106938      3000599798
# 11         70                 6000106938      3000599798
# 12         80                 6000106938      3000599798
# 13         90                 6000106938      3000599798
# 14        100                 6000106938      3000599798
# ...

# %%
df3 = pd.DataFrame()

def sld_val(data, df1):
    k = data.key.to_list()
    for i in range(len(k)):
        df3 = df1.iloc[]

# %%
for i in range(len(df1)):
    if df1['Line_Item'][i] == '' and df1['Line_Item'][i+1] == '' and df1['Line_Item'][i+2] == '' and df1['Line_Item'][i+3] == '' and df1['Line_Item'][i+4] == '' and df1['Line_Item'][i+5] == '':
        df1['long_des'][i-1] = df1['Description'][i] + " " + df1['Description'][i+1] + " " + df1['Description'][i+2]+ " " + df1['Description'][i+3]+ " " + df1['Description'][i+4]+ " " + df1['Description'][i+5]
        print(i, '6times')
    else:
        pass

# %%
data.key.values.tolist()

# %%
df1.drop(data.key.values.tolist(), axis = 0, inplace = True)

# %%
df1.reset_index(drop = True, inplace = True)
df1

# %%
df1.rename(columns = {'Line0AItem':'Line_Item'}, inplace=True)

# %%
df1

# %%
pp = df1[df1['Line_Item'] == '']
pp

# %%
df1.insert(8, 'short_des', '')
df1.insert(9, 'long_des', '')

df1['short_des'] = df1['Description']
df1

# %%
df1['Description'][169]

# %%
# for i in range(len(df1)):
#     if df1['Line_Item'][i] == '':
#         df1['long_des'][i-1] = df

# %%
# for i in range(len(df1)):
#     if df1['Line_Item'][i] == '':
#         df1['long_des'][i-1] = df1['Description'][i]

# %%
df1['long_des'][165]

# %%
# for i in range(len(df1)):
#     if df1['Line_Item'][i] == '':
#         df1['long_des'][i-1] = df1['Description'][i]

# %%
for i in range(len(df1)):
    if df1['Line_Item'][i] == '' and df1['Line_Item'][i+1] == '' and df1['Line_Item'][i+2] == '' and df1['Line_Item'][i+3] == '' and df1['Line_Item'][i+4] == '' and df1['Line_Item'][i+5] == '':
        df1['long_des'][i-1] = df1['Description'][i] + " " + df1['Description'][i+1] + " " + df1['Description'][i+2]+ " " + df1['Description'][i+3]+ " " + df1['Description'][i+4]+ " " + df1['Description'][i+5]
        print(i, '6times')
    
    elif df1['Line_Item'][i] == '' and df1['Line_Item'][i+1] == '' and df1['Line_Item'][i+2] == '' and df1['Line_Item'][i+3] == '' and df1['Line_Item'][i+4] == '':
        df1['long_des'][i-1] = df1['Description'][i] + " " + df1['Description'][i+1] + " " + df1['Description'][i+2]+ " " + df1['Description'][i+3]+ " " + df1['Description'][i+4]
        print(i, '5times')
    
    elif df1['Line_Item'][i] == '' and df1['Line_Item'][i+1] == '' and df1['Line_Item'][i+2] == '' and df1['Line_Item'][i+3] == '':
        df1['long_des'][i-1] = df1['Description'][i] + " " + df1['Description'][i+1] + " " + df1['Description'][i+2]+ " " + df1['Description'][i+3]
        print(i, '4times')
        
    elif df1['Line_Item'][i] == '' and df1['Line_Item'][i+1] == '' and df1['Line_Item'][i+2] == '':
        df1['long_des'][i-1] = df1['Description'][i] + " " + df1['Description'][i+1] + " " + df1['Description'][i+2]
        print(i, '3times')
        
    elif df1['Line_Item'][i] == '' and df1['Line_Item'][i+1] == '':
        df1['long_des'][i-1] = df1['Description'][i] + " " + df1['Description'][i+1]
        print('2 times')
        
    elif df1['Line_Item'][i] == '':
        df1['long_des'][i-1] = df1['Description'][i]
        print("1time")
    else:
        pass
df1

# %%
# data

# %%
df1[1:8]

# %%
df1[df1['Line_Item'] == ''].index.to_list()

# %%
df1.drop(df1[df1['Line_Item'] == ''].index.to_list(), axis = 0, inplace = True)
df1.reset_index(drop = True, inplace = True)
df1

# %%
df1.drop('Description', axis = 1, inplace = True)
df1

# %%
# 156 + 15

# %%
df1['long_des'] = np.where(df1['long_des'] == '', df1['short_des'], df1['long_des'])
df1

# %%
import re
filename1 = re.sub('.xlsx|.xls', '', filename)
filename1

# %%
df1.insert(4, "File Name", filename1)

# %%
df1[:1]

# %%
df1.columns

# %%
df1 = df1[['Service_Number', 'Requisition_No','RFQ_NO', 'Line_Item','File Name',
       'Folder_1', 'Folder_2', 'Folder_3', 'short_des', 'long_des', 'Quantity',
       'Unit', 'CUR', 'Unit_Price', 'Per_UOM']]

# %%
# df1[:1]

# %%
# rr[:1]

# %%
# rr = pd.read_excel('alok_sample_09_09_22.xlsx', 'Reference')
# rr.columns

# %%
df1

# %%
data

# %%
df1['File Name'][0]

# %%
df1.to_excel('3000190052-Schedule C - Pricing Attachment I_result.xlsx', index = False)

# %%
df1['long_des'][168]

# %%
for i in range(0, len(df1)):
    try:
        if ((df1['Line_Item'][i] == '' & df1['Line_Item'][i + 1] == '' )):
            print(df1['Line_Item'][i], df1['Line_Item'][i+1])
        else:
            print('hi')
    except:
        pass

# %%
for i in range(len(df1)):

# %%
df1['long_des'][165]

# %%
df1[df1['Line_Item'] == '']

# %%
df1

# %%
df1.to_excel('aramco_12.09.22.xlsx', index = False)

# %%
len(df1) + 19

# %%
len(l)

# %%
l = data.key.values.tolist()
l

# %%
list(data.key.values())

# %%
# ===============================================================================

# %%
df1[:1]

# %%
rr.columns

# %%
folder3

# %%
folder1

# %%
w = list(folder1.keys())
ww1 = (list(folder3.keys()))
print(w)
print(ww1)

# %%
def value_insert1(folder1, folder2, df1):

    qq = list(folder1.keys())
    qq1 = (list(folder2.keys()))

    a = None

    for i in qq:
        if i > qq1[-1]:
            a = i
            break

    lol = list(folder2.keys())
    lol1 = list(folder2.values())
#         df1 = df1[lol[0]:a]

    for i in range(len(lol)):
        try:
            df1['Folder_2'].iloc[range(lol[i] , lol[i+1])] = lol1[i]
        except IndexError:
            df1['Folder_2'].iloc[range(lol[i] , a)] = lol1[i]
    
    return df1

# %%
lol1 = list(folder2.keys())
lol1

# %%
folder3

# %%
value_insert(folder1, df1)

# %%
if folder3:
    lol = list(folder3.keys())
    lol1 = list(folder3.values())
#         df1 = df1[lol[0]:lol[-1]+1]
    for i in range(len(lol)):
        print(lol[i], lol[i+1])
#             df1['Folder_1'].iloc[range(lol[i] , lol[i+1])] = lol1[i]

# %%
folder2

# %%
data

# %%
df1.iloc[range(lol1[0], lol1[-1]+1)] = 'lol'

# %%
data

# %%
folder1

# %%
folder2

# %%
qq = list(folder1.keys())
qq1 = (list(folder2.keys()))

a = None
for i in qq:
    if i > qq1[-1]:
        a = i
        break
a

# %%
qq1

# %%
for i in qq:
    if i > qq1[-1]:
        print(i)
        break

# %%
qq3 = (list(folder3.keys()))
qq3

# %%
for i in qq1:
    if i > qq3[-1]:
        print(i)
        break

# %%
list(folder2.keys())

# %%
print(lol, len(lol))
print(lol1, len(lol1))

# %%
df1['Folder_1'].iloc[range(0,4)] = 'lol'

# %%
data

# %%
folder1

# %%
lol[-1] + 1

# %%
df3= df1[lol[0]:lol[-1] + 1]
df3

# %%
df1[lol[0]:lol[-1] + 1]

# %%
df1.iloc[range(lol[0], lol[-1] + 2)]
